# %% [markdown]
# ##### Let's finish up our discussion on subsetting data in Python first...

# %%
import pandas as pd # data frame library for Python
import numpy as np # scientific computing library for Python

data = pd.read_csv("D:\\CPSC392\\datasets\\02-titanic.csv")
data.head()
# Out:
#    passengerID                                               name   age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5                           Allen, Mr. William Henry  35.0
#
#       fare     sex  survived
# 0   7.2500    male         0
# 1  71.2833  female         1
# 2   7.9250  female         1
# 3  53.1000  female         1
# 4   8.0500    male         0

# %% [markdown]
# ##### To subset information based on a condition, we can use the following code:

# %%
survivors = data['survived'] == 1
males = data['sex'] == 'male'

# %% [markdown]
# ##### Let's try multiple conditions

# %% [markdown]
# ##### Q. How many females did not survive and had an age below 35?

# %%
data.head()
# Out:
#    passengerID                                               name   age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5                           Allen, Mr. William Henry  35.0
#
#       fare     sex  survived
# 0   7.2500    male         0
# 1  71.2833  female         1
# 2   7.9250  female         1
# 3  53.1000  female         1
# 4   8.0500    male         0

# %% [markdown]
# ##### We have so far talked about the data types of the attributes in the data but that is just how data is stored, there is another classification system for statistical data:
# * Categorical
# * Numerical
#     * Discrete
#     * Continuous
#
# ##### Q. What attributes are categorical in the Titanic data? Which ones are numerical?
# ##### Q. When would I use one over the other?
# ##### Q. Can I convert a numerical attribute to a categorical one? What about the other way around?

# %%
def num2cat(value):
    if 0 < value <= 20:
        return 'low'
    elif 20 < value <= 60:
        return 'mid'
    else:
        return 'high'

data['fare_cat'] = data['fare'].apply(num2cat)

# %%
data.groupby(['fare_cat']).size()
# Out:
# fare_cat
# high    137
# low     500
# mid     254
# dtype: int64

# %% [markdown]
# ##### Functions like groupby allow us to aggregate summary statistics by a category in a column

# %%
data.groupby(['fare_cat']).mean()
data.groupby(['fare_cat']).std()
# Out:
#           passengerID        age       fare  survived
# fare_cat
# high       242.094884  14.580105  88.164285  0.490463
# low        260.628278  12.253457   3.276833  0.451388
# mid        259.745901  17.342376  10.900287  0.499432

# %% [markdown]
# ###### Q. How can you be sure that fare_cat is the best version of a categorical version of fare?

# %% [markdown]
# ## Summary Statistics
# * information that gives a quick and simple description of the data.
# * used to summarize a set of observations

# %% [markdown]
# ###### Basic summary statistics include
# * min
# * max
# * mean
# * median
# * standard deviation
# * variance
# * number of missing values (not quite a summary statistic but equally important)

# %%
data.describe() # built-in summary statistics function
# Out:
#        passengerID         age        fare    survived
# count   891.000000  714.000000  891.000000  891.000000
# mean    446.000000   29.699118   32.204208    0.383838
# std     257.353842   14.526497   49.693429    0.486592
# min       1.000000    0.420000    0.000000    0.000000
# 25%     223.500000   20.125000    7.910400    0.000000
# 50%     446.000000   28.000000   14.454200    0.000000
# 75%     668.500000   38.000000   31.000000    1.000000
# max     891.000000   80.000000  512.329200    1.000000

# %% [markdown]
# ##### Q. Why does the describe function not provide the summary statistics for name and sex?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
# passengerID    891 non-null int64
# name           891 non-null object
# age            714 non-null float64
# fare           891 non-null float64
# sex            891 non-null object
# survived       891 non-null int64
# fare_cat       891 non-null object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 48.9+ KB

# %% [markdown]
# ##### Let's convert the sex attribute into a different form

# %%
data['isFemale'] = data['sex'].map({'female': 1, 'male': 0})

# %%
def converter(x):
    if x == 'female':
        return 1
    elif x == 'male':
        return 0


data['isFemale'] = data['sex'].apply(converter)

# %%
data.head(20)
# Out:
#     passengerID                                               name   age  \
# 0             1                            Braund, Mr. Owen Harris  22.0
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2             3                             Heikkinen, Miss. Laina  26.0
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4             5                           Allen, Mr. William Henry  35.0
# 5             6                                   Moran, Mr. James   NaN
# 6             7                            McCarthy, Mr. Timothy J  54.0
# 7             8                     Palsson, Master. Gosta Leonard   2.0
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10           11                    Sandstrom, Miss. Marguerite Rut   4.0
# 11           12                           Bonnell, Miss. Elizabeth  58.0
# 12           13                     Saundercock, Mr. William Henry  20.0
# 13           14                        Andersson, Mr. Anders Johan  39.0
# 14           15               Vestrom, Miss. Hulda Amanda Adolfina  14.0
# 15           16                   Hewlett, Mrs. (Mary D Kingcome)   55.0
# 16           17                               Rice, Master. Eugene   2.0
# 17           18                       Williams, Mr. Charles Eugene   NaN
# 18           19  Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0
# 19           20                            Masselmani, Mrs. Fatima   NaN
#
#        fare     sex  survived fare_cat  isFemale
# 0    7.2500    male         0      low         0
# 1   71.2833  female         1     high         1
# 2    7.9250  female         1      low         1
# 3   53.1000  female         1      mid         1
# 4    8.0500    male         0      low         0
# 5    8.4583    male         0      low         0
# 6   51.8625    male         0      mid         0
# 7   21.0750    male         0      mid         0
# 8   11.1333  female         1      low         1
# 9   30.0708  female         1      mid         1
# 10  16.7000  female         1      low         1
# 11  26.5500  female         1      mid         1
# 12   8.0500    male         0      low         0
# 13  31.2750    male         0      mid         0
# 14   7.8542  female         0      low         1
# 15  16.0000  female         1      low         1
# 16  29.1250    male         0      mid         0
# 17  13.0000    male         1      low         0
# 18  18.0000  female         0      low         1
# 19   7.2250  female         1      low         1

# %% [markdown]
# ##### Q. How do I get the counts for each category of isFemale attribute?

# %%
missingAge = data['age'].isnull()
data.loc[missingAge]
# Out:
#      passengerID                                      name  age     fare  \
# 5              6                          Moran, Mr. James  NaN   8.4583
# 17            18              Williams, Mr. Charles Eugene  NaN  13.0000
# 19            20                   Masselmani, Mrs. Fatima  NaN   7.2250
# 26            27                   Emir, Mr. Farred Chehab  NaN   7.2250
# 28            29             O'Dwyer, Miss. Ellen "Nellie"  NaN   7.8792
# ..           ...                                       ...  ...      ...
# 859          860                          Razi, Mr. Raihed  NaN   7.2292
# 863          864         Sage, Miss. Dorothy Edith "Dolly"  NaN  69.5500
# 868          869               van Melkebeke, Mr. Philemon  NaN   9.5000
# 878          879                        Laleff, Mr. Kristo  NaN   7.8958
# 888          889  Johnston, Miss. Catherine Helen "Carrie"  NaN  23.4500
#
#         sex  survived fare_cat  isFemale
# 5      male         0      low         0
# 17     male         1      low         0
# 19   female         1      low         1
# 26     male         0      low         0
# 28   female         1      low         1
# ..      ...       ...      ...       ...
# 859    male         0      low         0
# 863  female         0     high         1
# 868    male         0      low         0
# 878    male         0      low         0
# 888  female         0      mid         1
#
# [177 rows x 8 columns]

# %% [markdown]
# ##### We'll talk about how to estimate these missing values in the next class.
